# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/healthcare_dataset.csv')
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
df.head()
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Date of Admission          Doctor                   Hospital  \
# 0        2022-11-17  Patrick Parker           Wallace-Hamilton
# 1        2023-06-01   Diane Jackson  Burke, Griffin and Cooper
# 2        2019-01-09      Paul Baker                 Walton LLC
# 3        2020-05-02  Brian Chandler                 Garcia Ltd
# 4        2021-07-09  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Medicare    37490.983364          146       Elective
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %%
df.dtypes
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number             int64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  10000.000000    10000.000000  10000.000000
# mean      51.452200    25516.806778    300.082000
# std       19.588974    14067.292709    115.806027
# min       18.000000     1000.180837    101.000000
# 25%       35.000000    13506.523967    199.000000
# 50%       52.000000    25258.112566    299.000000
# 75%       68.000000    37733.913727    400.000000
# max       85.000000    49995.902283    500.000000

# %%
df.shape
# Out:
# (10000, 15)

# %%
#check for NULL values if any in each column
df.isnull().sum()
# There are no null values in our healthcare dataset as the value for all the columns are zero.
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Date of Admission and Discharge Date have dtype as object let's format it to datetime
for i in ['Date of Admission','Discharge Date']:
    df[i] = pd.to_datetime(df[i])

# %%
df.dtypes
# Out:
# Name                          object
# Age                            int64
# Gender                        object
# Blood Type                    object
# Medical Condition             object
# Date of Admission     datetime64[ns]
# Doctor                        object
# Hospital                      object
# Insurance Provider            object
# Billing Amount               float64
# Room Number                    int64
# Admission Type                object
# Discharge Date        datetime64[ns]
# Medication                    object
# Test Results                  object
# dtype: object

# %%
# 1. Room Allocation: Count the number of patients in each room
room_allocation = df['Room Number'].value_counts().reset_index()
room_allocation.columns = ['Room Number', 'Patient Count']
room_allocation
# Out:
#      Room Number  Patient Count
# 0            358             44
# 1            230             40
# 2            257             38
# 3            469             37
# 4            195             36
# ..           ...            ...
# 395          160             14
# 396          306             14
# 397          321             14
# 398          373             14
# 399          352             10
#
# [400 rows x 2 columns]

# %%
# 1. Admission Type Analysis
admission_type_counts = df['Admission Type'].value_counts()
admission_type_counts
# Out:
# Admission Type
# Urgent       3391
# Emergency    3367
# Elective     3242
# Name: count, dtype: int64

# %%
# Grouping by Admission Type and Medical Condition
admission_condition = df.groupby(['Admission Type', 'Medical Condition']).size().unstack().fillna(0)
admission_condition
# Out:
# Medical Condition  Arthritis  Asthma  Cancer  Diabetes  Hypertension  Obesity
# Admission Type
# Elective                 569     570     555       528           515      505
# Emergency                529     556     578       557           578      569
# Urgent                   552     582     570       538           595      554

# %%
# 2. Seasonal Trends in Admissions
df['Month'] = df['Date of Admission'].dt.month
df['Month']
# Out:
# 0       11
# 1        6
# 2        1
# 3        5
# 4        7
#         ..
# 9995     7
# 9996     1
# 9997     7
# 9998     2
# 9999     3
# Name: Month, Length: 10000, dtype: int32

# %%
# Group by Month and Medical Condition
monthly_admissions = df.groupby(['Month', 'Medical Condition']).size().unstack().fillna(0)
monthly_admissions
# Out:
# Medical Condition  Arthritis  Asthma  Cancer  Diabetes  Hypertension  Obesity
# Month
# 1                        120     133     164       144           135      141
# 2                        151     116     133       136           128      114
# 3                        136     141     142       156           124      151
# 4                        141     162     135       138           141      124
# 5                        134     158     143       110           149      148
# 6                        170     142     119       130           127      145
# 7                        135     141     145       134           144      128
# 8                        148     139     142       157           135      124
# 9                        117     134     141       124           153      132
# 10                       143     148     143       133           173      143
# 11                       116     152     147       129           132      144
# ...

# %%
#  1. Cost of Care by Condition
# cost_by_condition = df.groupby('Medical Condition')['Billing Amount'].mean().sort_values(ascending=False).reset_index()
# cost_by_condition
# # 2. Billing vs. Insurance
# insurance_billing = df.groupby('Insurance Provider')['Billing Amount'].mean().sort_values(ascending=False).reset_index()
# insurance_billing
# # 3. Insurance Provider and Medical Condition Cost Analysis
condition_insurance_cost = df.groupby(['Insurance Provider', 'Medical Condition'])['Billing Amount'].mean().unstack().fillna(0)
condition_insurance_cost
# Out:
# Medical Condition      Arthritis        Asthma        Cancer      Diabetes  \
# Insurance Provider
# Aetna               24694.858132  24761.515983  26333.940941  26703.077342
# Blue Cross          25989.515740  25701.560294  24382.770930  26599.036888
# Cigna               25189.873894  26604.203083  26437.599998  25496.295520
# Medicare            24206.381013  25820.568227  25118.720557  25468.553655
# UnitedHealthcare    25704.428629  24198.125815  25222.992960  26003.702541
#
# Medical Condition   Hypertension       Obesity
# Insurance Provider
# Aetna               26420.830930  26109.230890
# Blue Cross          26614.290980  24576.703308
# Cigna               24146.228564  26130.314831
# Medicare            24164.166294  25259.825969
# UnitedHealthcare    24708.016084  26586.298041

# %%
# Condition and Test Results: Analyzing how certain medical conditions relate to test results
# Rows = Unique Medical Conditions.
# Columns = Unique Test Results (Normal, Abnormal, Inconclusive).
# Values = Count of patients for each Medical Condition and Test Result combination.

condition_test_results = df.groupby(['Medical Condition', 'Test Results']).size().unstack().fillna(0)
condition_test_results
# Out:
# Test Results       Abnormal  Inconclusive  Normal
# Medical Condition
# Arthritis               555           553     542
# Asthma                  623           551     534
# Cancer                  577           556     570
# Diabetes                537           542     544
# Hypertension            602           554     532
# Obesity                 562           521     545

# %%
# Blood Type and Medical Conditions: Investigate whether certain blood types are associated with specific medical conditions
blood_condition = df.groupby(['Blood Type', 'Medical Condition']).size().unstack().fillna(0)
blood_condition
# Out:
# Medical Condition  Arthritis  Asthma  Cancer  Diabetes  Hypertension  Obesity
# Blood Type
# A+                       202     220     219       197           213      190
# A-                       202     208     218       206           212      192
# AB+                      219     199     208       207           211      214
# AB-                      204     210     195       214           225      227
# B+                       196     217     214       207           211      199
# B-                       186     218     221       221           196      210
# O+                       225     227     224       174           209      189
# O-                       216     209     204       197           211      207

# %% [markdown]
# # **Outlier detection**

# %%
cat=[]
num=[]
for i in df:
  if df[i].dtype=='object':
    cat.append(i)
  else:
    num.append(i)
cat,num
# Out:
# (['Name',
#   'Gender',
#   'Blood Type',
#   'Medical Condition',
#   'Doctor',
#   'Hospital',
#   'Insurance Provider',
#   'Admission Type',
#   'Medication',
#   'Test Results'],
#  ['Age',
#   'Date of Admission',
#   'Billing Amount',
#   'Room Number',
#   'Discharge Date',
#   'Month'])

# %%
import matplotlib.pyplot as plt

for i in num:
  # if df[i].dtype in ['int','float']:
  if df[i].dtypes=='int' or df[i].dtypes=='float':
    plt.boxplot(df[i])
    plt.title(i)
    plt.show()

# %% [markdown]
# # **Univarite Analysis**

# %%
df['Billing_Amount']=df['Billing Amount']*90

# %%
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
for i in num:

  if i!='Date of Admission' and i!='Discharge Date':
    print(i)
    print('------------------------------------')
    print(f'mean of {i} : {df[i].mean()}')
    print(f'min of {i}:{df[i].min()}')
    print(f'max of {i}:{df[i].max()}')
    print(f'median of {i}:{df[i].median()}')
    print(f'standard deviation of {i}:{df[i].std()}')
  # print(f'variance of {i}:{df[i].var()}')
    print()
    print()
# Out:
# Age
# ------------------------------------
# mean of Age : 51.4522
# min of Age:18
# max of Age:85
# median of Age:52.0
# standard deviation of Age:19.588973631836524
#
#
# Billing Amount
# ------------------------------------
# mean of Billing Amount : 25516.8067777384
# min of Billing Amount:1000.1808370217516
# max of Billing Amount:49995.90228322116
# median of Billing Amount:25258.112566373504
# standard deviation of Billing Amount:14067.292709226198
#
#
# Room Number
# ------------------------------------
# mean of Room Number : 300.082
# min of Room Number:101
# max of Room Number:500
# median of Room Number:299.0
# standard deviation of Room Number:115.8060265252975
#
#
# Month
# ------------------------------------
# mean of Month : 6.5239
# min of Month:1
# max of Month:12
# median of Month:7.0
# standard deviation of Month:3.448016483685291

# %% [markdown]
# # **Histogram**

# %%
for i in num:
  plt.hist(df[i],bins=20)
  plt.title(i)
  plt.xlabel(i)
  plt.ylabel('frequency')
  plt.show()

# %% [markdown]
# # **Categorical column**

# %%
for i in cat:
  print(i)
  print('------------------------')
  print(df[i].value_counts())
  print(df[i].nunique())
  print()
  print()
# Out:
# Name
# ------------------------
# Name
# Michael Johnson        7
# James Johnson          6
# Michael Miller         4
# Michelle Williams      4
# Scott Smith            4
#                       ..
# Sharon Rose            1
# Stephanie Knox         1
# Anthony Jones          1
# Melissa Perkins DVM    1
# Eric King              1
# Name: count, Length: 9378, dtype: int64
# 9378
#
#
# Gender
# ------------------------
# Gender
# Female    5075
# Male      4925
# Name: count, dtype: int64
# 2
#
#
# Blood Type
# ------------------------
# Blood Type
# AB-    1275
# AB+    1258
# B-     1252
# O+     1248
# O-     1244
# B+     1244
# A+     1241
# A-     1238
# Name: count, dtype: int64
# 8
#
#
# Medical Condition
# ------------------------
# Medical Condition
# Asthma          1708
# Cancer          1703
# Hypertension    1688
# Arthritis       1650
# Obesity         1628
# Diabetes        1623
# Name: count, dtype: int64
# 6
#
#
# Doctor
# ------------------------
# Doctor
# ...

# %%
df.nunique()
# Out:
# Name                   9378
# Age                      68
# Gender                    2
# Blood Type                8
# Medical Condition         6
# Date of Admission      1815
# Doctor                 9416
# Hospital               8639
# Insurance Provider        5
# Billing Amount        10000
# Room Number             400
# Admission Type            3
# Discharge Date         1834
# Medication                5
# Test Results              3
# Month                    12
# Billing_Amount        10000
# dtype: int64

# %% [markdown]
# # **Countplot**

# %%
import seaborn as sns
for i in cat:
  sns.countplot(x=df[i])
  plt.title(i)
  plt.show()

# %% [markdown]
# # **Bivariate analysis**

# %%
var1=df.corr(numeric_only=True)
sns.heatmap(var1,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # **Relation between numerical and categorical columns**

# %%
for i in cat:
  for j in num:
    print(f'{i} and {j} analysis')
    print('------------------------------------------------------------------')
    print(df[[i,j]].groupby(i).agg(['mean','median','min','max','std','count']))
    print('___________________________________________________________________')
    print()
    print()
# Out:
# Name and Age analysis
# ------------------------------------------------------------------
#                   Age
#                  mean median min max std count
# Name
# Aaron Burnett    54.0   54.0  54  54 NaN     1
# Aaron Calderon   35.0   35.0  35  35 NaN     1
# Aaron Coleman    69.0   69.0  69  69 NaN     1
# Aaron Daugherty  34.0   34.0  34  34 NaN     1
# Aaron Davis      22.0   22.0  22  22 NaN     1
# ...               ...    ...  ..  ..  ..   ...
# Zachary Wood     36.0   36.0  36  36 NaN     1
# Zachary Yates    37.0   37.0  37  37 NaN     1
# Zoe Adkins DVM   30.0   30.0  30  30 NaN     1
# Zoe Henderson    67.0   67.0  67  67 NaN     1
# Zoe Moore        74.0   74.0  74  74 NaN     1
#
# [9378 rows x 6 columns]
# ___________________________________________________________________
#
#
# Name and Date of Admission analysis
# ------------------------------------------------------------------
#                 Date of Admission
# ...

# %%
df
#calculate the no: of days patients got admitted in hospital
df['Days Hospitalized'] = (df['Discharge Date'] - df['Date of Admission']).dt.days
df['Days Hospitalized'] = df['Days Hospitalized'].astype(int)
df['Days Hospitalized']
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %% [markdown]
# # **Pie plot**

# %%
plt.pie(df['Gender'].value_counts(),labels=df['Gender'].value_counts().index,autopct='%1.0f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# What is the total billing amount for top 10 hospitals?
# you are trying to access a column named 'Hospital' in the top_10 Series,
#  but it doesn't exist as a column. The top_10 Series likely has 'Hospital'
#  as its index, not a column, due to the groupby and sort_values operations.
top_10=df.groupby('Hospital')['Billing Amount'].sum().sort_values(ascending=False)[:10]
top_10=top_10.reset_index()
top_10
# Out:
#          Hospital  Billing Amount
# 0  Smith and Sons   477638.881124
# 1       Smith PLC   432283.548554
# 2       Smith Ltd   428163.073062
# 3       Smith Inc   351463.888372
# 4    Williams LLC   327522.472644
# 5    Thomas Group   327045.374505
# 6     Johnson Ltd   305971.192470
# 7  Davis and Sons   293452.520353
# 8       Jones Inc   290351.193848
# 9       Brown LLC   284695.674489

# %%
sns.barplot(x=top_10['Hospital'],y=top_10['Billing Amount'])
plt.xticks(rotation=90)
plt.title('Top 10 hospital by billing amount')
plt.show()

# %%
# Who are the top 20 doctors by billing amount?
top_20=df.groupby('Doctor')['Billing Amount'].sum().sort_values(ascending=False)[:20]
top_20=top_20.reset_index()
top_20
# Out:
#                Doctor  Billing Amount
# 0     Michael Johnson   181576.474893
# 1   Christopher Davis   159763.924755
# 2      Jennifer Smith   149972.685230
# 3        Robert Brown   147747.938399
# 4        Angela Jones   141867.200639
# 5       Robert Miller   129493.950567
# 6          John Jones   127864.878980
# 7        Leslie Jones   123228.453342
# 8     Jessica Johnson   122383.408771
# 9        Daniel Smith   121830.506139
# 10       Joseph Smith   118915.905553
# 11    Heather Johnson   115707.262494
# 12      David Johnson   114247.020721
# 13   Matthew Williams   113630.017307
# 14     Brian Williams   112313.289949
# 15         Jason Hall   111697.290076
# 16  William Rodriguez   111158.002683
# 17  Christopher Jones   108305.442506
# 18      Michael Smith   107729.864100
# 19      Mark Thompson   106350.632435

# %%
sns.barplot(x=top_20['Doctor'],y=top_20['Billing Amount'])

plt.xticks(rotation=90)
plt.title('Top 20 doctors by billing amount')
plt.show()

# %%
# # Which medical condition generated the highest average billing among male and female?
# Grouping data by medical condition and gender then calculating the mean of billing amount
medical_gender_billing = df.groupby(['Medical Condition','Gender'])[['Billing Amount']].mean().reset_index()
medical_gender_billing
# Out:
#    Medical Condition  Gender  Billing Amount
# 0          Arthritis  Female    24692.417417
# 1          Arthritis    Male    25670.983684
# 2             Asthma  Female    25672.743141
# 3             Asthma    Male    25148.724551
# 4             Cancer  Female    25370.465132
# 5             Cancer    Male    25722.399683
# 6           Diabetes  Female    26369.383481
# 7           Diabetes    Male    25740.384845
# 8       Hypertension  Female    25126.230138
# 9       Hypertension    Male    25268.489378
# 10           Obesity  Female    25664.778361
# 11           Obesity    Male    25780.313444

# %%
sns.barplot(x= medical_gender_billing['Medical Condition'],
            y= medical_gender_billing['Billing Amount'],
            hue = medical_gender_billing['Gender'],ci = None,
            palette="Accent")
plt.title(f'Barplot of Medical Condition vs Billing Amount')
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-99-5f1a0ec1941b>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x= medical_gender_billing['Medical Condition'],
